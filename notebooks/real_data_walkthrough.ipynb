# %% [markdown]
# # Real Data Walkthrough
#
# This notebook reviews the UCI postural-transitions results saved under `reports/results`.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
REPORTS = ROOT / 'reports' / 'results'
MODELS = ROOT / 'models' / 'results'

metrics = json.loads((REPORTS / 'metrics.json').read_text())
preds = pd.read_csv(REPORTS / 'posture_predictions.csv')
metrics['best_model'], MODELS

# %%
pd.DataFrame({
    'model': ['gradient_boosting', 'knn'],
    'accuracy': [metrics['models']['gradient_boosting']['accuracy'], metrics['models']['knn']['accuracy']],
    'macro_f1': [metrics['models']['gradient_boosting']['macro_f1'], metrics['models']['knn']['macro_f1']],
})

# %%
preds[['true_activity', 'true_group', 'selected_prediction', 'recommendation']].head(10)
